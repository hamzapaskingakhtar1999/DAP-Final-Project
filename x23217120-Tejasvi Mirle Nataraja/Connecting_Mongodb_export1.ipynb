# %%
#pip install "pymongo[srv]"

import pymongo
import json

# %%
# Connect to MongoDB Atlas
client = pymongo.MongoClient("mongodb+srv://mntejasvimysore:INkKBzZabDFr8u3x@clusterncidap1.gbew9wh.mongodb.net/?retryWrites=true&w=majority&appName=Clusterncidap1")
db = client.get_database('DAP_PROJECT_2024')
collection = db['tmdb_popular_movie']

# %%
# Read JSON file
with open('popular_movie_data.json') as f:
    data = json.load(f)

# %%
# Insert JSON data into MongoDB
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('661ec0a782636514977a4fb5'), ObjectId('661ec0a782636514977a4fb6'), ObjectId('661ec0a782636514977a4fb7'), ObjectId('661ec0a782636514977a4fb8'), ObjectId('661ec0a782636514977a4fb9'), ObjectId('661ec0a782636514977a4fba'), ObjectId('661ec0a782636514977a4fbb'), ObjectId('661ec0a782636514977a4fbc'), ObjectId('661ec0a782636514977a4fbd'), ObjectId('661ec0a782636514977a4fbe'), ObjectId('661ec0a782636514977a4fbf'), ObjectId('661ec0a782636514977a4fc0'), ObjectId('661ec0a782636514977a4fc1'), ObjectId('661ec0a782636514977a4fc2'), ObjectId('661ec0a782636514977a4fc3'), ObjectId('661ec0a782636514977a4fc4'), ObjectId('661ec0a782636514977a4fc5'), ObjectId('661ec0a782636514977a4fc6'), ObjectId('661ec0a782636514977a4fc7'), ObjectId('661ec0a782636514977a4fc8'), ObjectId('661ec0a782636514977a4fc9'), ObjectId('661ec0a782636514977a4fca'), ObjectId('661ec0a782636514977a4fcb'), ObjectId('661ec0a782636514977a4fcc'), ObjectId('661ec0a782636514977a4fcd'), ObjectId('661ec0a782636514977a
# ...

# %%
# Connect to MongoDB Atlas
client = pymongo.MongoClient("mongodb+srv://mntejasvimysore:INkKBzZabDFr8u3x@clusterncidap1.gbew9wh.mongodb.net/?retryWrites=true&w=majority&appName=Clusterncidap1")
db = client.get_database('DAP_PROJECT_2024')
collection = db['tmdb_rated_movie']

# %%
# Read JSON file
with open('rated_movie_data.json') as f1:
    data1 = json.load(f1)

# %%
# Insert JSON data into MongoDB
collection.insert_many(data1)
# Out:
# InsertManyResult([ObjectId('661ec16e82636514977a58cb'), ObjectId('661ec16e82636514977a58cc'), ObjectId('661ec16e82636514977a58cd'), ObjectId('661ec16e82636514977a58ce'), ObjectId('661ec16e82636514977a58cf'), ObjectId('661ec16e82636514977a58d0'), ObjectId('661ec16e82636514977a58d1'), ObjectId('661ec16e82636514977a58d2'), ObjectId('661ec16e82636514977a58d3'), ObjectId('661ec16e82636514977a58d4'), ObjectId('661ec16e82636514977a58d5'), ObjectId('661ec16e82636514977a58d6'), ObjectId('661ec16e82636514977a58d7'), ObjectId('661ec16e82636514977a58d8'), ObjectId('661ec16e82636514977a58d9'), ObjectId('661ec16e82636514977a58da'), ObjectId('661ec16e82636514977a58db'), ObjectId('661ec16e82636514977a58dc'), ObjectId('661ec16e82636514977a58dd'), ObjectId('661ec16e82636514977a58de'), ObjectId('661ec16e82636514977a58df'), ObjectId('661ec16e82636514977a58e0'), ObjectId('661ec16e82636514977a58e1'), ObjectId('661ec16e82636514977a58e2'), ObjectId('661ec16e82636514977a58e3'), ObjectId('661ec16e82636514977a
# ...
