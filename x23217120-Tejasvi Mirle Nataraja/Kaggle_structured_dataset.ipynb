# %% [markdown]
# # Loading of necessary libraries

# %%
import numpy as np  # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
import os  # operating system library
import matplotlib.pyplot as plt  # basic visualisation library
import seaborn as sns  # advanced visualisations
import ast  # Abstact Syntax Trees
import itertools  # Iterating tools
import re  # Regular Expressions

# %% [markdown]
# # Descriptive Statistics

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.head(10)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
# 7   8                                                NaN         0
# 8   9  [{'id': 256377, 'name': 'The Muppet Collection...         0
# 9  10                                                NaN   6000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# ...

# %%
test.head(5)
# Out:
#      id                              belongs_to_collection   budget  \
# 0  3001  [{'id': 34055, 'name': 'Pokémon Collection', '...        0
# 1  3002                                                NaN    88000
# 2  3003                                                NaN        0
# 3  3004                                                NaN  6800000
# 4  3005                                                NaN  2000000
#
#                                               genres  \
# 0  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 1  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'n...
# 4  [{'id': 36, 'name': 'History'}, {'id': 99, 'na...
#
#                                             homepage    imdb_id  \
# 0  http://www.pokemon.com/us/movies/movie-pokemon...  tt1226251
# 1                                                NaN  tt0051380
# ...

# %%
train.dtypes
# Out:
# id                         int64
# belongs_to_collection     object
# budget                     int64
# genres                    object
# homepage                  object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity               float64
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# Keywords                  object
# cast                      object
# crew                      object
# revenue                    int64
# dtype: object

# %%
train.dtypes
# Out:
# id                         int64
# belongs_to_collection     object
# budget                     int64
# genres                    object
# homepage                  object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity               float64
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# Keywords                  object
# cast                      object
# crew                      object
# revenue                    int64
# dtype: object

# %%
test.describe().T
# Out:
#              count          mean           std          min          25%  \
# id          4398.0  5.199500e+03  1.269738e+03  3001.000000  4100.250000
# budget      4398.0  2.264929e+07  3.689991e+07     0.000000     0.000000
# popularity  4398.0  8.550230e+00  1.220901e+01     0.000001     3.895186
# runtime     4394.0  1.076222e+02  2.105829e+01     0.000000    94.000000
#
#                      50%           75%           max
# id          5.199500e+03  6.298750e+03  7.398000e+03
# budget      7.450000e+06  2.800000e+07  2.600000e+08
# popularity  7.482242e+00  1.093852e+01  5.474883e+02
# runtime     1.040000e+02  1.180000e+02  3.200000e+02

# %%
train.describe().T
# Out:
#              count          mean           std       min           25%  \
# id          3000.0  1.500500e+03  8.661697e+02  1.000000  7.507500e+02
# budget      3000.0  2.253133e+07  3.702609e+07  0.000000  0.000000e+00
# popularity  3000.0  8.463274e+00  1.210400e+01  0.000001  4.018053e+00
# runtime     2998.0  1.078566e+02  2.208643e+01  0.000000  9.400000e+01
# revenue     3000.0  6.672585e+07  1.375323e+08  1.000000  2.379808e+06
#
#                      50%           75%           max
# id          1.500500e+03  2.250250e+03  3.000000e+03
# budget      8.000000e+06  2.900000e+07  3.800000e+08
# popularity  7.374861e+00  1.089098e+01  2.943370e+02
# runtime     1.040000e+02  1.180000e+02  3.380000e+02
# revenue     1.680707e+07  6.891920e+07  1.519558e+09

# %% [markdown]
# # Check for shape of the datasets

# %%
train_shape = train.shape
test_shape = test.shape
print("Train dataset has {} rows and {} columns.".format(train_shape[0], train_shape[1]))
print("Test dataset has {} rows and {} columns.".format(test_shape[0], test_shape[1]))
# Out:
# Train dataset has 3000 rows and 23 columns.
# Test dataset has 4398 rows and 22 columns.

# %% [markdown]
# # Check for duplicates in each of the dataset

# %%
if sum(train.duplicated()) == 0:
    print("There are no duplicates in a train dataset.")
else:
    print("There are {} duplicates in a train dataset.".format(sum(train.duplicated())))
    
if sum(train.duplicated()) == 0:
    print("There are no duplicates in a test dataset.")
else:
    print("There are {} duplicates in a test dataset.".format(sum(train.duplicated())))
# Out:
# There are no duplicates in a train dataset.
# There are no duplicates in a test dataset.

# %% [markdown]
# # Check for missing values

# %%
#calculate the percentage of missing values in each column of train set
train_pct_nans = round(train.isnull().sum()/train_shape[0]*100,2).to_frame().sort_values(by=[0], ascending=False)
#calculate the percentage of missing values in each column of test set
test_pct_nans = round(test.isnull().sum()/test_shape[0]*100,2).to_frame().sort_values(by=[0], ascending=False)

pct_nans = pd.concat([train_pct_nans,test_pct_nans],axis=1, sort=False).reset_index()
pct_nans.columns = ["column","train","test"]
#unpivots the DataFrame from wide to long format
melted = pct_nans.melt(id_vars="column").rename(columns=str.title)
melted
#This format is useful for visualizing and comparing the percentage of missing values across different columns in the train and test datasets.
# Out:
#                    Column Variable  Value
# 0   belongs_to_collection    train  79.87
# 1                homepage    train  68.47
# 2                 tagline    train  19.90
# 3                Keywords    train   9.20
# 4    production_companies    train   5.20
# 5    production_countries    train   1.83
# 6        spoken_languages    train   0.67
# 7                    crew    train   0.53
# 8                    cast    train   0.43
# 9                overview    train   0.27
# 10                 genres    train   0.23
# 11                runtime    train   0.07
# 12            poster_path    train   0.03
# 13                  title    train   0.00
# 14                 status    train   0.00
# 15                     id    train   0.00
# 16           release_date    train   0.00
# 17             popularity    train   0.00
# 18         original_title    train   0.00
# 19      original_language    train   0.00
# 20                imdb_id    train   0.00
# ...

# %%
# create a bar chart to check for percentage of missing values in both test and train set
sns.set_style("darkgrid")
plt.figure(figsize=(20,8))
sns.barplot(x="Column", y="Value", hue="Variable", data=melted)

plt.axhline(10, ls="--")
plt.xticks(rotation=90, fontsize=13)
plt.title("Percentage of missing values", fontsize=13)
plt.ylabel("Missing values [%]", fontsize=13)
plt.show()

# %% [markdown]
# # Data Processing : Concatenating train and test datasets

# %%
train["screen"] = "train" #here 'screen' is a column for which each row is assigned with 'train values'
test["screen"] = "test"
whole_data = pd.concat([train,test], sort=False)
whole_data.head(2)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
#
#                                               genres homepage    imdb_id  \
# 0                     [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  tt0368933
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
#
#                                             overview  popularity  ... runtime  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...    93.0
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...   113.0
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ...

# %%
#dropping missing values from 'release_date'
whole_data.dropna(subset=["release_date"], inplace=True)

# %%
whole_data
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 4393  7394                                                NaN  42000000
# 4394  7395  [{'id': 146534, 'name': 'Without a Paddle Coll...  19000000
# 4395  7396                                                NaN  16000000
# 4396  7397                                                NaN   2000000
# 4397  7398                                                NaN     64000
#
#                                                  genres  \
# ...

# %% [markdown]
# # Store the data in postgreSQL

# %%
import pandas as pd
from sqlalchemy import create_engine


# Create SQLAlchemy engine
engine = create_engine(f'postgresql://postgres:system@localhost:5432/postgres')

# Store the DataFrame in PostgreSQL
whole_data.to_sql('whole_data', engine, index=False, if_exists='replace')
# Out:
# 397

# %% [markdown]
# # Retrieve the data from postgreSQL and store in a dataframe

# %%
# Create SQLAlchemy engine
engine = create_engine(f'postgresql://postgres:system@localhost:5432/postgres')

# Query to retrieve the whole table
query = f"SELECT * FROM whole_data;"

# Retrieve data from PostgreSQL into a Pandas DataFrame
whole_data_from_db = pd.read_sql(query, engine)

# Display the first few rows of the DataFrame
print(whole_data_from_db.head())
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                               None   3300000
# 3   4                                               None   1200000
# 4   5                                               None         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                               None  tt2637294                en
# 1                               None  tt0368933                en
# ...
